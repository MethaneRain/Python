# %%
import xarray as xr
#import hvplot.xarray 
import cartopy.crs as crs
import geoviews as gv

# %%
air_ds = xr.tutorial.open_dataset('air_temperature').load()
print(air_ds)
air_temp = air_ds.air.isel(time=0)
proj = crs.Orthographic(-90, 30)

air_plot = air_temp.hvplot.quadmesh(
    'lon', 'lat', projection=proj, project=True, global_extent=True,
    width=525, height=450, cmap='gist_rainbow_r', rasterize=True)

air_plot * gv.feature.coastline
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, lon: 53, time: 2920)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 241.2 242.5 243.5 ... 296.49 296.19 295.69
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...
# :DynamicMap   []
#    :Overlay
#       .Image.I     :Image   [lon,lat]   (air)
#       .Coastline.I :Feature   [Longitude,Latitude]

# %%
list(air_ds.variables)
# Out:
# ['lat', 'air', 'lon', 'time']

# %%
gv.feature.rivers

# %%
air_ds.variables["lat"]
# Out:
# <xarray.IndexVariable 'lat' (lat: 25)>
# array([75. , 72.5, 70. , 67.5, 65. , 62.5, 60. , 57.5, 55. , 52.5, 50. , 47.5,
#        45. , 42.5, 40. , 37.5, 35. , 32.5, 30. , 27.5, 25. , 22.5, 20. , 17.5,
#        15. ], dtype=float32)
# Attributes:
#     standard_name:  latitude
#     long_name:      Latitude
#     units:          degrees_north
#     axis:           Y

# %%
air_ds = xr.tutorial.open_dataset('air_temperature').load()
air = air_ds.air
air_ds
longs = 180.-air_ds.lon[:]
longs
# Out:
# <xarray.DataArray 'lon' (lon: 53)>
# array([ -20. ,  -22.5,  -25. ,  -27.5,  -30. ,  -32.5,  -35. ,  -37.5,  -40. ,
#         -42.5,  -45. ,  -47.5,  -50. ,  -52.5,  -55. ,  -57.5,  -60. ,  -62.5,
#         -65. ,  -67.5,  -70. ,  -72.5,  -75. ,  -77.5,  -80. ,  -82.5,  -85. ,
#         -87.5,  -90. ,  -92.5,  -95. ,  -97.5, -100. , -102.5, -105. , -107.5,
#        -110. , -112.5, -115. , -117.5, -120. , -122.5, -125. , -127.5, -130. ,
#        -132.5, -135. , -137.5, -140. , -142.5, -145. , -147.5, -150. ],
#       dtype=float32)
# Coordinates:
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0

# %%
air2d = air.isel(time=200)
air2d.hvplot(width=400)
# Out:
# :Image   [lon,lat]   (air)

# %%
cd ~/Downloads/
# Out:
# /Users/chowdahead/Downloads

# %%
ls *nc
# Out:
# OR_GLM-L2-LCFA_G16_s20193602359400_e20193610000000_c20193610000024.nc
# hgt.2016.nc
# nws_precip_1day_20191215_conus.nc
# rectilinear_grid_3D.nc
# wrfout_v2_Lambert.nc

# %%
air_ds = xr.open_dataset("hgt.2016.nc")
air_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 73, level: 17, lon: 144, time: 1464)
# Coordinates:
#   * level    (level) float32 1000.0 925.0 850.0 700.0 ... 50.0 30.0 20.0 10.0
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 2016-01-01 ... 2016-12-31T18:00:00
# Data variables:
#     hgt      (time, level, lat, lon) float32 ...
# Attributes:
#     Conventions:    COARDS
#     title:          4x daily NMC reanalysis (2014)
#     history:        created 2013/12 by Hoop (netCDF2.3)
#     description:    Data is from NMC initialized reanalysis\n(4x/day).  It co...
#     platform:       Model
#     References:     http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reana...
#     dataset_title:  NCEP-NCAR Reanalysis 1

# %%
print(air_ds)
air_temp = air_ds.hgt.isel(time=7,level=5)
proj = crs.LambertConformal()

air_plot = air_temp.hvplot(
    'lon', 'lat', projection=proj,
    width=525, height=450, cmap='gist_rainbow_r')

air_plot * gv.feature.coastline
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 73, level: 17, lon: 144, time: 1464)
# Coordinates:
#   * level    (level) float32 1000.0 925.0 850.0 700.0 ... 50.0 30.0 20.0 10.0
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 2016-01-01 ... 2016-12-31T18:00:00
# Data variables:
#     hgt      (time, level, lat, lon) float32 ...
# Attributes:
#     Conventions:    COARDS
#     title:          4x daily NMC reanalysis (2014)
#     history:        created 2013/12 by Hoop (netCDF2.3)
#     description:    Data is from NMC initialized reanalysis\n(4x/day).  It co...
#     platform:       Model
#     References:     http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reana...
#     dataset_title:  NCEP-NCAR Reanalysis 1
# :Overlay
#    .Image.I     :Image   [lon,lat]   (hgt)
#    .Coastline.I :Feature   [Longitude,Latitude]

# %%
import hvplot.pandas
import pandas as pd
import numpy as np
idx = pd.date_range('1/1/2000', periods=1000)
df  = pd.DataFrame(np.random.randn(1000, 4), index=idx, columns=list('ABCD')).cumsum()

df.hvplot()
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
import iris
import numpy as np
import xarray as xr
import holoviews as hv
import geoviews as gv
import geoviews.feature as gf

from cartopy import crs
from geoviews import opts

gv.extension('matplotlib')

gv.output(size=150)
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
xr.open_dataset("hgt.2016.nc").load().isel(time=slice(0, 10))
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 73, level: 17, lon: 144, time: 10)
# Coordinates:
#   * level    (level) float32 1000.0 925.0 850.0 700.0 ... 50.0 30.0 20.0 10.0
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 2016-01-01 ... 2016-01-03T06:00:00
# Data variables:
#     hgt      (time, level, lat, lon) float32 -118.0 -118.0 ... 32007.0 32007.0
# Attributes:
#     Conventions:    COARDS
#     title:          4x daily NMC reanalysis (2014)
#     history:        created 2013/12 by Hoop (netCDF2.3)
#     description:    Data is from NMC initialized reanalysis\n(4x/day).  It co...
#     platform:       Model
#     References:     http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reana...
#     dataset_title:  NCEP-NCAR Reanalysis 1

# %%
xr_ensemble = xr.open_dataset("hgt.2016.nc").load().isel(time=slice(0, 10)).isel(level=slice(0, 1))
xr_ensemble
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 73, level: 1, lon: 144, time: 10)
# Coordinates:
#   * level    (level) float32 1000.0
#   * lat      (lat) float32 90.0 87.5 85.0 82.5 80.0 ... -82.5 -85.0 -87.5 -90.0
#   * lon      (lon) float32 0.0 2.5 5.0 7.5 10.0 ... 350.0 352.5 355.0 357.5
#   * time     (time) datetime64[ns] 2016-01-01 ... 2016-01-03T06:00:00
# Data variables:
#     hgt      (time, level, lat, lon) float32 -118.0 -118.0 ... -65.0 -65.0
# Attributes:
#     Conventions:    COARDS
#     title:          4x daily NMC reanalysis (2014)
#     history:        created 2013/12 by Hoop (netCDF2.3)
#     description:    Data is from NMC initialized reanalysis\n(4x/day).  It co...
#     platform:       Model
#     References:     http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reana...
#     dataset_title:  NCEP-NCAR Reanalysis 1

# %%
kdims = ['time', 'lon', 'lat',"level"]
vdims = ['hgt']

xr_dataset = gv.Dataset(xr_ensemble, kdims=kdims, vdims=vdims)
#iris_dataset = gv.Dataset(iris_ensemble, kdims=kdims, vdims=vdims)

# %%
print(repr(xr_dataset))
# Out:
# :Dataset   [time,lon,lat,level]   (hgt)

# %%
print("XArray time type: %s" % xr_dataset.get_dimension_type('time'))
# Out:
# XArray time type: <class 'numpy.datetime64'>

# %%
hv.Dimension.type_formatters[np.datetime64] = '%Y-%m-%d'

# %%
(xr_dataset.to(gv.Image, ['lon', 'lat']) * gf.coastline).opts(
    opts.Image(colorbar=True,projection=crs.LambertConformal(), cmap='nipy_spectral', xaxis=None, yaxis=None))
# Out:
# :HoloMap   [time,level]
#    :Overlay
#       .Image.I     :Image   [lon,lat]   (hgt)
#       .Coastline.I :Feature   [Longitude,Latitude]
