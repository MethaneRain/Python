# %%
import metpy
# Out:
# /Users/chowdahead/miniconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /Users/chowdahead/miniconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
cd Downloads/
# Out:
# /Users/chowdahead/Downloads

# %%
metpy.plots.ctables.convert_gempak_table("fire_detection_3.9_inverted_256.tbl")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-102693f0b15f> in <module>
# ----> 1 metpy.convert_gempak_table("fire_detection_3.9_inverted_256.tbl")
#
# AttributeError: module 'metpy' has no attribute 'convert_gempak_table'

# %%
import metpy as metpy

# %%
from metpy.plots import ctables
import Color_Bar

# %%
list(ctables.colortables)
# Out:
# ['NWSVelocity',
#  'NWSVelocity_r',
#  'ir_tv1',
#  'ir_tv1_r',
#  'NWSSpectrumWidth',
#  'NWSSpectrumWidth_r',
#  'WVCIMSS',
#  'WVCIMSS_r',
#  'NWS8bitVel',
#  'NWS8bitVel_r',
#  'Carbone42',
#  'Carbone42_r',
#  'ir_tpc',
#  'ir_tpc_r',
#  'NWSStormClearReflectivity',
#  'NWSStormClearReflectivity_r',
#  'NWSReflectivity',
#  'NWSReflectivity_r',
#  'ir_drgb',
#  'ir_drgb_r',
#  'wv_tpc',
#  'wv_tpc_r',
#  'test',
#  'test_r',
#  'precipitation',
#  'precipitation_r',
#  'NWSReflectivityExpanded',
#  'NWSReflectivityExpanded_r',
#  'rainbow',
#  'rainbow_r',
#  'viridis',
#  'viridis_r',
#  'ir_bd',
#  'ir_bd_r',
#  'ir_rgbv',
#  'ir_rgbv_r']

# %%
ctables.colortables.
# Out:
# [(1.0, 0.0, 0.0),
#  (0.858824, 0.0, 0.0),
#  (0.760784, 0.0, 0.0),
#  (0.635294, 0.0, 0.0),
#  (0.490196, 0.0, 0.0),
#  (0.541176, 0.109804, 0.0),
#  (0.603922, 0.223529, 0.0),
#  (0.65098, 0.333333, 0.0),
#  (0.713725, 0.443137, 0.0),
#  (0.760784, 0.556863, 0.0),
#  (0.823529, 0.666667, 0.0),
#  (0.87451, 0.776471, 0.0),
#  (0.937255, 0.890196, 0.0),
#  (1.0, 1.0, 0.0),
#  (0.890196, 0.937255, 0.0),
#  (0.776471, 0.87451, 0.0),
#  (0.666667, 0.823529, 0.0),
#  (0.556863, 0.760784, 0.0),
#  (0.443137, 0.713725, 0.0),
#  (0.333333, 0.65098, 0.0),
#  (0.223529, 0.603922, 0.0),
#  (0.109804, 0.541176, 0.0),
#  (0.0, 0.490196, 0.0),
#  (0.0, 0.541176, 0.109804),
#  (0.0, 0.603922, 0.223529),
#  (0.0, 0.65098, 0.333333),
#  (0.0, 0.713725, 0.443137),
#  (0.0, 0.760784, 0.556863),
#  (0.0, 0.823529, 0.666667),
#  (0.0, 0.87451, 0.776471),
#  (0.0, 0.937255, 0.890196),
#  (0.0, 1.0, 1.0),
#  (0.0, 0.890196, 0.937255),
#  (0.0, 0.776471, 0.87451),
#  (0.0, 0.666667, 0.823529),
#  (0.0, 0.556863, 0.760784),
#  (0.0, 0.443137, 0.713725),
#  (0.0, 0.333333, 0.65098),
#  (0.0, 0.223529, 0.603922),
#  (0.0, 0.109804, 0.541176),
#  (0.0, 0.0, 0.490196),
#  (0.109804, 0.0, 0.541176),
#  (0.223529, 0.0, 0.603922),
#  (0.333333, 0.0, 0.65098),
#  (0.443137, 0.0, 0.713725),
#  (0.556863, 0.0, 0.760784),
#  (0.666667, 0.0, 0.823529),
#  (0.776471, 0.0, 0.87451),
#  (0.890196, 0.0, 0.937255),
#  (1.0, 0.0, 1.0),
#  (0.87451, 0.0, 0.87451),
#  (0.745098, 0.0, 0.745098),
#  (0.619608, 0.0, 0.619608),
#  (0.490196, 0.0, 0.490196),
#  (0.364706, 0.0, 0.364706),
#  (0.239216, 0.0, 0.239216),
#  (0.109804, 0.0, 0.109804)]

# %%
ctables.convert_gempak_table?

# %%
ctables.convert_gempak_table("fire_detection_3.9_inverted_256.tbl","out")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-1e34ccba778e> in <module>
# ----> 1 ctables.convert_gempak_table("fire_detection_3.9_inverted_256.tbl","out")
#
# ~/miniconda3/lib/python3.7/site-packages/metpy/plots/ctables.py in convert_gempak_table(infile, outfile)
#     117     for line in infile:
#     118         if not line.startswith('!') and line.strip():
# --> 119             r, g, b = map(int, line.split())
#     120             outfile.write('({0:f}, {1:f}, {2:f})\n'.format(r / 255, g / 255, b / 255))
#     121
#
# ValueError: invalid literal for int() with base 10: 'f'

# %%
import pandas as pd
ass = pd.read_csv("fire_ctable.csv")

# %%
ass
# Out:
#        R    G    B
# 0    255  255  255
# 1    253  253  253
# 2    252  252  252
# 3    250  250  250
# 4    249  249  249
# 5    248  248  248
# 6    246  246  246
# 7    245  245  245
# 8    243  243  243
# 9    242  242  242
# 10   240  240  240
# 11   239  239  239
# 12   237  237  237
# 13   236  236  236
# 14   235  235  235
# 15   233  233  233
# 16   232  232  232
# 17   230  230  230
# 18   229  229  229
# 19   227  227  227
# 20   226  226  226
# 21   224  224  224
# 22   223  223  223
# 23   221  221  221
# 24   220  220  220
# 25   219  219  219
# 26   217  217  217
# 27   216  216  216
# 28   214  214  214
# 29   213  213  213
# ..   ...  ...  ...
# 226  255   78    0
# 227  255   75    0
# 228  255   73    0
# 229  255   70    0
# 230  255   67    0
# 231  255   65    0
# 232  255   62    0
# 233  255   59    0
# 234  255   57    0
# 235  255   54    0
# 236  255   51    0
# 237  255   48    0
# 238  255   46    0
# 239  255   43    0
# 240  255   40    0
# 241  255   38    0
# 242  255   35    0
# 243  255   32    0
# 244  255   30    0
# 245  255   27    0
# 246  255   24    0
# 247  255   22    0
# 248  255   19    0
# 249  255   16    0
# 250  255   13    0
# 251  255   11    0
# 252  255    8    0
# 253  255    5    0
# 254  255    3    0
# 255  255    0    0
#
# [256 rows x 3 columns]

# %%
ass.R[0]
# Out:
# 255

# %%
colors=[(30,30,30),(50,50,50),(65,65,65),(80,80,80),(90,90,90),(100,100,100),(108,108,108),(114,114,114),
        (120,120,120),(130,130,130),(150,150,150),(180,180,180),(190,190,190),(200,200,200),(211,211,211),
        (220,220,220),(230,230,230),(244,244,244),(255, 255, 255),(255, 255, 255),(255, 255, 255),
        (230,250,230),(0, 100, 0),(50,200,50),(200,255,47),(255,255,0),(255,200,50),(255,150,80),
        (255,100,50),(255,0,0),(180,0,0),(140,0,0),(100,0,0),(150,10,0),(208,32,144),(150,32,144),
        (108,32,144),(0,0,100),(0,0,255),(0,150,150),(135,206,250)]

colors = []
for i in range(len(ass.R)):
    colors.append((ass.R[i],ass.G[i],ass.B[i]))

vort_cmap = Color_Bar.create_colormap(colors, bit=True)
